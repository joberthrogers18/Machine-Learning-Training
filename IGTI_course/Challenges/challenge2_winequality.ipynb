# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-39bb7c8e-1190-4e88-a035-61f1dab0a3b1" name="files[]" multiple disabled />
#      <output id="result-39bb7c8e-1190-4e88-a035-61f1dab0a3b1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving winequality-red.csv to winequality-red (1).csv
# ...

# %%
dataset = pd.read_csv('winequality-red.csv', sep=";")
dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
dataset.shape
# Out:
# (1599, 12)

# %%
# no null values
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
dataset.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  ...      alcohol      quality
# count    1599.000000       1599.000000  ...  1599.000000  1599.000000
# mean        8.319637          0.527821  ...    10.422983     5.636023
# std         1.741096          0.179060  ...     1.065668     0.807569
# min         4.600000          0.120000  ...     8.400000     3.000000
# 25%         7.100000          0.390000  ...     9.500000     5.000000
# 50%         7.900000          0.520000  ...    10.200000     6.000000
# 75%         9.200000          0.640000  ...    11.100000     6.000000
# max        15.900000          1.580000  ...    14.900000     8.000000
#
# [8 rows x 12 columns]

# %%
dataset.loc[dataset['quality'] == 5].count()
# Out:
# fixed acidity           681
# volatile acidity        681
# citric acid             681
# residual sugar          681
# chlorides               681
# free sulfur dioxide     681
# total sulfur dioxide    681
# density                 681
# pH                      681
# sulphates               681
# alcohol                 681
# quality                 681
# dtype: int64

# %%
# median of dataset 
dataset['residual sugar'].median
# Out:
# <bound method Series.median of 0       1.9
# 1       2.6
# 2       2.3
# 3       1.9
# 4       1.9
#        ...
# 1594    2.0
# 1595    2.2
# 1596    2.3
# 1597    2.0
# 1598    3.6
# Name: residual sugar, Length: 1599, dtype: float64>

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(dataset.corr(),
            annot = True,
            fmt = '.2f',
            cmap='Blues')

# %%
dataset.head(20)
# Out:
#     fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0             7.4             0.700         0.00  ...       0.56      9.4        5
# 1             7.8             0.880         0.00  ...       0.68      9.8        5
# 2             7.8             0.760         0.04  ...       0.65      9.8        5
# 3            11.2             0.280         0.56  ...       0.58      9.8        6
# 4             7.4             0.700         0.00  ...       0.56      9.4        5
# 5             7.4             0.660         0.00  ...       0.56      9.4        5
# 6             7.9             0.600         0.06  ...       0.46      9.4        5
# 7             7.3             0.650         0.00  ...       0.47     10.0        7
# 8             7.8             0.580         0.02  ...       0.57      9.5        7
# 9             7.5             0.500         0.36  ...       0.80     10.5        5
# ...

# %%
# plot boxplot
dataset.boxplot()

# %%
x = dataset.drop(columns=['quality'])
y = dataset.iloc[:, -1]

# %%
# OPTIONAL ->  transform the predict classes in only 2; greater than 5 (good wine), least 5 ( worst wine )
y = np.where(y <= 5, 0, 1)

# %%
print(x.shape)
print(y.shape)
# Out:
# (1599, 11)
# (1599,)

# %%
# normalize the operations with min max scaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

x = scaler.fit_transform(x)

# %%
pd.DataFrame(x).describe()
# Out:
#                 0            1   ...           9            10
# count  1599.000000  1599.000000  ...  1599.000000  1599.000000
# mean      0.329171     0.279329  ...     0.196496     0.311228
# std       0.154079     0.122644  ...     0.101501     0.163949
# min       0.000000     0.000000  ...     0.000000     0.000000
# 25%       0.221239     0.184932  ...     0.131737     0.169231
# 50%       0.292035     0.273973  ...     0.173653     0.276923
# 75%       0.407080     0.356164  ...     0.239521     0.415385
# max       1.000000     1.000000  ...     1.000000     1.000000
#
# [8 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=1)

# %%
print('train shape: ', x_train.shape)
print('test shape: ', x_test.shape)
# Out:
# train shape:  (1119, 11)
# test shape:  (480, 11)

# %%
from sklearn.metrics import accuracy_score

# %%
# using algorithm k neighboors
from sklearn.neighbors import KNeighborsClassifier

class_kneigh = KNeighborsClassifier(n_neighbors=5)
class_kneigh.fit(x_train, y_train)

kn_pred = class_kneigh.predict(x_test)

print(accuracy_score(y_test, kn_pred))
# Out:
# 0.6958333333333333

# %%
# use algorithm decision tree
from sklearn.tree import DecisionTreeClassifier

clf_tree = DecisionTreeClassifier()
clf_tree.fit(x_train, y_train)

tree_pred = clf_tree.predict(x_test)
print(accuracy_score(y_test, tree_pred))
# Out:
# 0.7645833333333333

# %%
# use algorithm random forest
from sklearn.ensemble import RandomForestClassifier

clf_forest = RandomForestClassifier(max_depth=10, random_state=1)
clf_forest.fit(x_train, y_train)

forest_pred = clf_forest.predict(x_test)
print(accuracy_score(y_test, forest_pred))
# Out:
# 0.8041666666666667

# %%
# algorithm SVM
from sklearn.svm import SVC

clf_svm = SVC(gamma='auto', kernel='rbf')
clf_svm =clf_svm.fit(x_train, y_train)

svm_pred = clf_svm.predict(x_test)
print(accuracy_score(y_test, svm_pred))
# Out:
# 0.7458333333333333

# %%
# implement neural network
from sklearn.neural_network import MLPClassifier

clf_mlp = MLPClassifier(alpha=1e-5, hidden_layer_sizes=(5, 5), random_state=1)
clf_mlp.fit(x_train, y_train)

mlp_pred = clf_mlp.predict(x_test)
print(accuracy_score(y_test, mlp_pred))
# Out:
# 0.74375
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
